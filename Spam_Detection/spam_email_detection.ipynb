# %%
"""
Project: AI-Based Spam Email Detection System
Internship: Shris Tech
Domain: Artificial Intelligence
"""

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("spam.csv")
df
# Out:
#    label                                               text
# 0    ham                    Hey are we still meeting today?
# 1   spam  Congratulations! You have won a free lottery t...
# 2    ham                  Please call me when you are free.
# 3   spam  URGENT! Your account has been compromised. Cli...
# 4    ham              Can you send me the notes from class?
# 5   spam   Win cash prizes instantly by clicking this link.
# 6    ham                         Let's have lunch tomorrow.
# 7   spam  You have been selected for a free gift card. A...
# 8    ham               Are you coming to the party tonight?
# 9   spam       Limited time offer! Buy now and get 50% off.
# 10  spam  Win ₹10000 cash now by clicking this exclusive...
# 11  spam  Your bank account is blocked verify details im...
# 12  spam   Limited time offer buy now and get huge discount
# 13  spam  You have won a free mobile recharge claim inst...
# 14  spam  URGENT update your KYC to avoid account suspen...
# 15  spam              Get free gift vouchers click here now
# 16  spam  Congratulations you are selected for a lucky draw
# 17  spam           Claim your prize now offer expires today
# 18  spam      Your loan is approved click here to get money
# 19  spam              Exclusive deal just for you buy today
# 20  spam  Win ₹10000 cash now by clicking this exclusive...
# 21  spam  Your bank account is blocked verify details im...
# 22  spam   Limited time offer buy now and get huge discount
# 23  spam  You have won a free mobile recharge claim inst...
# 24  spam  URGENT update your KYC to avoid account suspen...
# 25  spam              Get free gift vouchers click here now
# 26  spam  Congratulations you are selected for a lucky draw
# 27  spam           Claim your prize now offer expires today
# 28  spam      Your loan is approved click here to get money
# 29  spam              Exclusive deal just for you buy today
# 30   ham                  Hey did you finish the assignment
# 31   ham          Can we reschedule our meeting to tomorrow
# 32   ham             Please send me the documents when free
# 33   ham                    Are you coming to college today
# 34   ham                    Let us know once you reach home
# 35   ham     Reminder about the project submission deadline
# 36   ham                     Call me when you are available
# 37   ham                   Let us have lunch together today
# 38   ham                 Did you check the timetable update
# 39   ham                     Meeting postponed to next week

# %%
df.info()
df['label'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   40 non-null     object
#  1   text    40 non-null     object
# dtypes: object(2)
# memory usage: 772.0+ bytes
# label
# spam    25
# ham     15
# Name: count, dtype: int64

# %%
import re

# %%
def clean_text(text):
    text = text.lower()                      # convert to lowercase
    text = re.sub(r'[^a-zA-Z]', ' ', text)   # remove numbers & symbols
    text = re.sub(r'\s+', ' ', text)         # remove extra spaces
    return text

# %%
df['clean_text'] = df['text'].apply(clean_text)
df[['text', 'clean_text']]
# Out:
#                                                  text  \
# 0                     Hey are we still meeting today?
# 1   Congratulations! You have won a free lottery t...
# 2                   Please call me when you are free.
# 3   URGENT! Your account has been compromised. Cli...
# 4               Can you send me the notes from class?
# 5    Win cash prizes instantly by clicking this link.
# 6                          Let's have lunch tomorrow.
# 7   You have been selected for a free gift card. A...
# 8                Are you coming to the party tonight?
# 9        Limited time offer! Buy now and get 50% off.
# 10  Win ₹10000 cash now by clicking this exclusive...
# 11  Your bank account is blocked verify details im...
# 12   Limited time offer buy now and get huge discount
# 13  You have won a free mobile recharge claim inst...
# 14  URGENT update your KYC to avoid account suspen...
# 15              Get free gift vouchers click here now
# 16  Congratulations you are selected for a lucky draw
# 17           Claim your prize now offer expires today
# 18      Your loan is approved click here to get money
# 19              Exclusive deal just for you buy today
# 20  Win ₹10000 cash now by clicking this exclusive...
# 21  Your bank account is blocked verify details im...
# 22   Limited time offer buy now and get huge discount
# 23  You have won a free mobile recharge claim inst...
# 24  URGENT update your KYC to avoid account suspen...
# 25              Get free gift vouchers click here now
# 26  Congratulations you are selected for a lucky draw
# 27           Claim your prize now offer expires today
# 28      Your loan is approved click here to get money
# 29              Exclusive deal just for you buy today
# 30                  Hey did you finish the assignment
# 31          Can we reschedule our meeting to tomorrow
# 32             Please send me the documents when free
# 33                    Are you coming to college today
# 34                    Let us know once you reach home
# 35     Reminder about the project submission deadline
# 36                     Call me when you are available
# 37                   Let us have lunch together today
# 38                 Did you check the timetable update
# 39                     Meeting postponed to next week
#
#                                            clean_text
# 0                     hey are we still meeting today
# 1   congratulations you have won a free lottery ti...
# 2                   please call me when you are free
# 3   urgent your account has been compromised click...
# 4               can you send me the notes from class
# 5    win cash prizes instantly by clicking this link
# 6                          let s have lunch tomorrow
# 7   you have been selected for a free gift card ac...
# 8                are you coming to the party tonight
# 9             limited time offer buy now and get off
# 10  win cash now by clicking this exclusive offer ...
# 11  your bank account is blocked verify details im...
# 12   limited time offer buy now and get huge discount
# 13  you have won a free mobile recharge claim inst...
# 14  urgent update your kyc to avoid account suspen...
# 15              get free gift vouchers click here now
# 16  congratulations you are selected for a lucky draw
# 17           claim your prize now offer expires today
# 18      your loan is approved click here to get money
# 19              exclusive deal just for you buy today
# 20  win cash now by clicking this exclusive offer ...
# 21  your bank account is blocked verify details im...
# 22   limited time offer buy now and get huge discount
# 23  you have won a free mobile recharge claim inst...
# 24  urgent update your kyc to avoid account suspen...
# 25              get free gift vouchers click here now
# 26  congratulations you are selected for a lucky draw
# 27           claim your prize now offer expires today
# 28      your loan is approved click here to get money
# 29              exclusive deal just for you buy today
# 30                  hey did you finish the assignment
# 31          can we reschedule our meeting to tomorrow
# 32             please send me the documents when free
# 33                    are you coming to college today
# 34                    let us know once you reach home
# 35     reminder about the project submission deadline
# 36                     call me when you are available
# 37                   let us have lunch together today
# 38                 did you check the timetable update
# 39                     meeting postponed to next week

# %%
df.head()
# Out:
#   label                                               text  \
# 0   ham                    Hey are we still meeting today?
# 1  spam  Congratulations! You have won a free lottery t...
# 2   ham                  Please call me when you are free.
# 3  spam  URGENT! Your account has been compromised. Cli...
# 4   ham              Can you send me the notes from class?
#
#                                           clean_text
# 0                    hey are we still meeting today
# 1  congratulations you have won a free lottery ti...
# 2                  please call me when you are free
# 3  urgent your account has been compromised click...
# 4              can you send me the notes from class

# %%
X = df['clean_text']
y = df['label']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(stop_words='english')
X_tfidf = tfidf.fit_transform(X)

# %%
X_tfidf.shape
# Out:
# (40, 79)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf, y, test_size=0.2, random_state=42
)

# %%
X_train.shape, X_test.shape
# Out:
# ((32, 79), (8, 79))

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#          ham       1.00      1.00      1.00         2
#         spam       1.00      1.00      1.00         6
#
#     accuracy                           1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8

# %%
test_msg = ["Congratulations! You have won a free prize. Click now!"]

test_msg_clean = [clean_text(test_msg[0])]
test_msg_tfidf = tfidf.transform(test_msg_clean)

prediction = model.predict(test_msg_tfidf)
print("Message:", test_msg[0])
print("Prediction:", prediction[0])
# Out:
# Message: Congratulations! You have won a free prize. Click now!
# Prediction: spam

# %%
def predict_spam(message):
    message_clean = clean_text(message)
    message_tfidf = tfidf.transform([message_clean])
    prediction = model.predict(message_tfidf)
    return prediction[0]

# %%
msg = input("Enter an email/message: ")
result = predict_spam(msg)
print("Prediction:", result)
# Out:
# Enter an email/message:  Congratulations! You are selected for the prize of 1 Million.
# Prediction: spam

# %%
"""
## Limitations of the System
- The accuracy of the spam detection system depends heavily on the size and quality of the dataset.
- With a small dataset, the model may misclassify some messages.
- The system currently supports only text-based input.
- More advanced NLP techniques could further improve performance.
"""

# %%
"""
## Future Scope
- The dataset can be expanded with real-world email data for better accuracy.
- More advanced models such as Logistic Regression or Deep Learning can be used.
- The system can be integrated with an email client for real-time spam filtering.
- Language support can be extended beyond English.
"""

# %%
"""## Conclusion
The AI-based spam email detection system successfully classifies messages as spam or non-spam
using machine learning techniques. By applying text preprocessing, TF-IDF feature extraction, and a Naive Bayes classifier,
the system demonstrates how artificial intelligence can automate spam detection efficiently.
"""
